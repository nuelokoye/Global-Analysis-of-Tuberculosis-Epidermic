# %% [markdown]
# # Global Analysis of Tuberculosis Epidermic using Python
#
# Tuberculosis (TB) is caused by bacteria (Mycobacterium tuberculosis) that most often affect the lungs and is spread from person to person through the air. Tuberculosis is curable and preventable.
#
# The aim of this project is to provide an in-depth analysis of this data and to answer the following questions:
#
# 1. Estimated Tuberculosis cases per year
# 2. Estimated Number of people living with Tuberculosis and HIV
# 3. Estimated number of Tuberculosis incidents per year
# 4. Estimated number of death from Tuberculosis per year
# 5. The Top 10 Countries with Tuberculosis Incident.
# 6. The Top 10 Countries with Tuberculosis deaths.

# %% [markdown]
# ## 1.) Import Libraries
#
# Import Libraries, Dataset and the data dictonary so as to fully understand the data i am working with.

# %%
# import libraries
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset as pandas dataframe
tb = pd.read_csv("./TB_burden_countries_2023-04-06.csv")

# preview first 10 rows of dataset
tb.head(10)
# Out:
#        country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0  Afghanistan   AF  AFG            4         EMR  2000   19542982
# 1  Afghanistan   AF  AFG            4         EMR  2001   19688632
# 2  Afghanistan   AF  AFG            4         EMR  2002   21000256
# 3  Afghanistan   AF  AFG            4         EMR  2003   22645130
# 4  Afghanistan   AF  AFG            4         EMR  2004   23553551
# 5  Afghanistan   AF  AFG            4         EMR  2005   24411191
# 6  Afghanistan   AF  AFG            4         EMR  2006   25442944
# 7  Afghanistan   AF  AFG            4         EMR  2007   25903301
# 8  Afghanistan   AF  AFG            4         EMR  2008   26427199
# 9  Afghanistan   AF  AFG            4         EMR  2009   27385307
#
#    e_inc_100k  e_inc_100k_lo  e_inc_100k_hi  ...  cfr  cfr_lo  cfr_hi  \
# 0       190.0          122.0          271.0  ...  NaN     NaN     NaN
# 1       189.0          122.0          271.0  ...  NaN     NaN     NaN
# 2       189.0          122.0          270.0  ...  NaN     NaN     NaN
# 3       189.0          122.0          270.0  ...  NaN     NaN     NaN
# 4       189.0          122.0          270.0  ...  NaN     NaN     NaN
# 5       189.0          122.0          270.0  ...  NaN     NaN     NaN
# 6       189.0          122.0          270.0  ...  NaN     NaN     NaN
# 7       189.0          122.0          270.0  ...  NaN     NaN     NaN
# 8       189.0          122.0          271.0  ...  NaN     NaN     NaN
# 9       189.0          122.0          271.0  ...  NaN     NaN     NaN
#
#    cfr_pct  cfr_pct_lo  cfr_pct_hi  c_newinc_100k  c_cdr  c_cdr_lo  c_cdr_hi
# 0      NaN         NaN         NaN           36.0   19.0      13.0      30.0
# 1      NaN         NaN         NaN           51.0   27.0      19.0      42.0
# 2      NaN         NaN         NaN           66.0   35.0      24.0      54.0
# 3      NaN         NaN         NaN           61.0   32.0      23.0      50.0
# 4      NaN         NaN         NaN           78.0   41.0      29.0      64.0
# 5      NaN         NaN         NaN           89.0   47.0      33.0      73.0
# 6      NaN         NaN         NaN          100.0   53.0      37.0      82.0
# 7      NaN         NaN         NaN          111.0   59.0      41.0      91.0
# 8      NaN         NaN         NaN          107.0   57.0      40.0      88.0
# 9      NaN         NaN         NaN           95.0   50.0      35.0      78.0
#
# [10 rows x 50 columns]

# %%
# preview the shape of the data
tb.shape
# Out:
# (4702, 50)

# %%
# preview the summary of the data
tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4702 entries, 0 to 4701
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   4702 non-null   object
#  1   iso2                      4680 non-null   object
#  2   iso3                      4702 non-null   object
#  3   iso_numeric               4702 non-null   int64
#  4   g_whoregion               4702 non-null   object
#  5   year                      4702 non-null   int64
#  6   e_pop_num                 4702 non-null   int64
#  7   e_inc_100k                4702 non-null   float64
#  8   e_inc_100k_lo             4702 non-null   float64
#  9   e_inc_100k_hi             4702 non-null   float64
#  10  e_inc_num                 4702 non-null   int64
#  11  e_inc_num_lo              4702 non-null   int64
#  12  e_inc_num_hi              4702 non-null   int64
#  13  e_tbhiv_prct              4057 non-null   float64
#  14  e_tbhiv_prct_lo           4057 non-null   float64
#  15  e_tbhiv_prct_hi           4057 non-null   float64
#  16  e_inc_tbhiv_100k          4057 non-null   float64
#  17  e_inc_tbhiv_100k_lo       4057 non-null   float64
#  18  e_inc_tbhiv_100k_hi       4057 non-null   float64
#  19  e_inc_tbhiv_num           4057 non-null   float64
#  20  e_inc_tbhiv_num_lo        4057 non-null   float64
#  21  e_inc_tbhiv_num_hi        4057 non-null   float64
#  22  e_mort_exc_tbhiv_100k     4680 non-null   float64
#  23  e_mort_exc_tbhiv_100k_lo  4680 non-null   float64
#  24  e_mort_exc_tbhiv_100k_hi  4680 non-null   float64
#  25  e_mort_exc_tbhiv_num      4680 non-null   float64
#  26  e_mort_exc_tbhiv_num_lo   4680 non-null   float64
#  27  e_mort_exc_tbhiv_num_hi   4680 non-null   float64
#  28  e_mort_tbhiv_100k         4680 non-null   float64
#  29  e_mort_tbhiv_100k_lo      4680 non-null   float64
#  30  e_mort_tbhiv_100k_hi      4680 non-null   float64
#  31  e_mort_tbhiv_num          4680 non-null   float64
#  32  e_mort_tbhiv_num_lo       4680 non-null   float64
#  33  e_mort_tbhiv_num_hi       4680 non-null   float64
#  34  e_mort_100k               4680 non-null   float64
#  35  e_mort_100k_lo            4680 non-null   float64
#  36  e_mort_100k_hi            4680 non-null   float64
#  37  e_mort_num                4680 non-null   float64
#  38  e_mort_num_lo             4680 non-null   float64
#  39  e_mort_num_hi             4680 non-null   float64
#  40  cfr                       209 non-null    float64
#  41  cfr_lo                    209 non-null    float64
#  42  cfr_hi                    209 non-null    float64
#  43  cfr_pct                   209 non-null    float64
#  44  cfr_pct_lo                209 non-null    float64
#  45  cfr_pct_hi                209 non-null    float64
#  46  c_newinc_100k             4529 non-null   float64
#  47  c_cdr                     4424 non-null   float64
#  48  c_cdr_lo                  4424 non-null   float64
#  49  c_cdr_hi                  4424 non-null   float64
# dtypes: float64(40), int64(6), object(4)
# memory usage: 1.8+ MB

# %%
#I imported the data dictonary to be able to understand the field properly. 

data_dic = pd.read_csv("./tb_data_dictoonary.csv")

#preview the top 15 rows of the data 

data_dic.head(15)
# Out:
#     variable_name                 dataset  \
# 0         country  Country identification
# 1     g_whoregion  Country identification
# 2     iso_numeric  Country identification
# 3            iso2  Country identification
# 4            iso3  Country identification
# 5           c_cdr               Estimates
# 6        c_cdr_hi               Estimates
# 7        c_cdr_lo               Estimates
# 8   c_newinc_100k               Estimates
# 9             cfr               Estimates
# 10         cfr_hi               Estimates
# 11         cfr_lo               Estimates
# 12        cfr_pct               Estimates
# 13     cfr_pct_hi               Estimates
# 14     cfr_pct_lo               Estimates
#
#                                             code_list  \
# 0                                                 NaN
# 1   AFR=Africa; AMR=Americas; EMR=Eastern Mediterr...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                            definition
# 0                           Country or territory name
# 1                                          WHO region
# 2                  ISO numeric country/territory code
# 3              ISO 2-character country/territory code
# 4              ISO 3-character country/territory code
# 5   Case detection rate (all forms) [also known as...
# 6   Case detection rate (all forms) [also known as...
# 7   Case detection rate (all forms) [also known as...
# 8   Case notification rate, which is the total of ...
# 9                    Estimated TB case fatality ratio
# 10       Estimated TB case fatality ratio: high bound
# 11        Estimated TB case fatality ratio: low bound
# 12  Estimated TB case fatality ratio expressed as ...
# 13  Estimated TB case fatality ratio: high bound e...
# 14  Estimated TB case fatality ratio: low bound ex...

# %% [markdown]
# ## 2.) Data Cleaning
#
# I removed unwanted columns, duplicate values and manipulated the dataset

# %%
# Check for null values 

tb.isnull()
# Out:
#       country   iso2   iso3  iso_numeric  g_whoregion   year  e_pop_num  \
# 0       False  False  False        False        False  False      False
# 1       False  False  False        False        False  False      False
# 2       False  False  False        False        False  False      False
# 3       False  False  False        False        False  False      False
# 4       False  False  False        False        False  False      False
# ...       ...    ...    ...          ...          ...    ...        ...
# 4697    False  False  False        False        False  False      False
# 4698    False  False  False        False        False  False      False
# 4699    False  False  False        False        False  False      False
# 4700    False  False  False        False        False  False      False
# 4701    False  False  False        False        False  False      False
#
#       e_inc_100k  e_inc_100k_lo  e_inc_100k_hi  ...    cfr  cfr_lo  cfr_hi  \
# 0          False          False          False  ...   True    True    True
# 1          False          False          False  ...   True    True    True
# 2          False          False          False  ...   True    True    True
# 3          False          False          False  ...   True    True    True
# 4          False          False          False  ...   True    True    True
# ...          ...            ...            ...  ...    ...     ...     ...
# 4697       False          False          False  ...   True    True    True
# 4698       False          False          False  ...   True    True    True
# 4699       False          False          False  ...   True    True    True
# 4700       False          False          False  ...   True    True    True
# 4701       False          False          False  ...  False   False   False
#
#       cfr_pct  cfr_pct_lo  cfr_pct_hi  c_newinc_100k  c_cdr  c_cdr_lo  \
# 0        True        True        True          False  False     False
# 1        True        True        True          False  False     False
# 2        True        True        True          False  False     False
# 3        True        True        True          False  False     False
# 4        True        True        True          False  False     False
# ...       ...         ...         ...            ...    ...       ...
# 4697     True        True        True          False  False     False
# 4698     True        True        True          False  False     False
# 4699     True        True        True          False  False     False
# 4700     True        True        True          False  False     False
# 4701    False       False       False          False  False     False
#
#       c_cdr_hi
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 4697     False
# 4698     False
# 4699     False
# 4700     False
# 4701     False
#
# [4702 rows x 50 columns]

# %%
#rows missing in each column
tb.isnull().sum()
# Out:
# country                        0
# iso2                          22
# iso3                           0
# iso_numeric                    0
# g_whoregion                    0
# year                           0
# e_pop_num                      0
# e_inc_100k                     0
# e_inc_100k_lo                  0
# e_inc_100k_hi                  0
# e_inc_num                      0
# e_inc_num_lo                   0
# e_inc_num_hi                   0
# e_tbhiv_prct                 645
# e_tbhiv_prct_lo              645
# e_tbhiv_prct_hi              645
# e_inc_tbhiv_100k             645
# e_inc_tbhiv_100k_lo          645
# e_inc_tbhiv_100k_hi          645
# e_inc_tbhiv_num              645
# e_inc_tbhiv_num_lo           645
# e_inc_tbhiv_num_hi           645
# e_mort_exc_tbhiv_100k         22
# e_mort_exc_tbhiv_100k_lo      22
# e_mort_exc_tbhiv_100k_hi      22
# e_mort_exc_tbhiv_num          22
# e_mort_exc_tbhiv_num_lo       22
# e_mort_exc_tbhiv_num_hi       22
# e_mort_tbhiv_100k             22
# e_mort_tbhiv_100k_lo          22
# e_mort_tbhiv_100k_hi          22
# e_mort_tbhiv_num              22
# e_mort_tbhiv_num_lo           22
# e_mort_tbhiv_num_hi           22
# e_mort_100k                   22
# e_mort_100k_lo                22
# e_mort_100k_hi                22
# e_mort_num                    22
# e_mort_num_lo                 22
# e_mort_num_hi                 22
# cfr                         4493
# cfr_lo                      4493
# cfr_hi                      4493
# cfr_pct                     4493
# cfr_pct_lo                  4493
# cfr_pct_hi                  4493
# c_newinc_100k                173
# c_cdr                        278
# c_cdr_lo                     278
# c_cdr_hi                     278
# dtype: int64

# %%
tb.columns
# Out:
# Index(['country', 'iso2', 'iso3', 'iso_numeric', 'g_whoregion', 'year',
#        'e_pop_num', 'e_inc_100k', 'e_inc_100k_lo', 'e_inc_100k_hi',
#        'e_inc_num', 'e_inc_num_lo', 'e_inc_num_hi', 'e_tbhiv_prct',
#        'e_tbhiv_prct_lo', 'e_tbhiv_prct_hi', 'e_inc_tbhiv_100k',
#        'e_inc_tbhiv_100k_lo', 'e_inc_tbhiv_100k_hi', 'e_inc_tbhiv_num',
#        'e_inc_tbhiv_num_lo', 'e_inc_tbhiv_num_hi', 'e_mort_exc_tbhiv_100k',
#        'e_mort_exc_tbhiv_100k_lo', 'e_mort_exc_tbhiv_100k_hi',
#        'e_mort_exc_tbhiv_num', 'e_mort_exc_tbhiv_num_lo',
#        'e_mort_exc_tbhiv_num_hi', 'e_mort_tbhiv_100k', 'e_mort_tbhiv_100k_lo',
#        'e_mort_tbhiv_100k_hi', 'e_mort_tbhiv_num', 'e_mort_tbhiv_num_lo',
#        'e_mort_tbhiv_num_hi', 'e_mort_100k', 'e_mort_100k_lo',
#        'e_mort_100k_hi', 'e_mort_num', 'e_mort_num_lo', 'e_mort_num_hi', 'cfr',
#        'cfr_lo', 'cfr_hi', 'cfr_pct', 'cfr_pct_lo', 'cfr_pct_hi',
#        'c_newinc_100k', 'c_cdr', 'c_cdr_lo', 'c_cdr_hi'],
#       dtype='object')

# %%
#Drop columns that are not needed
tb_new = tb.drop(["iso2","iso_numeric","e_inc_100k_lo","e_inc_100k_hi","e_inc_num_lo","e_inc_num_hi","e_tbhiv_prct_lo","e_tbhiv_prct_hi","e_inc_tbhiv_100k_lo","e_inc_tbhiv_100k_hi","e_inc_tbhiv_num_lo","e_inc_tbhiv_num_hi","e_mort_exc_tbhiv_100k_lo","e_mort_exc_tbhiv_100k_hi","e_mort_exc_tbhiv_num_lo","e_mort_exc_tbhiv_num_hi","e_mort_tbhiv_100k_lo","e_mort_tbhiv_100k_hi","e_mort_tbhiv_num_lo","e_mort_tbhiv_num_hi","e_mort_100k_lo","e_mort_100k_hi","e_mort_num_lo","e_mort_num_hi","cfr","cfr_lo","cfr_hi","cfr_pct_lo","cfr_pct_hi","cfr_pct",
"c_cdr_lo","c_cdr_hi"], axis= 1)
display(tb_new)
# Out:
#           country iso3 g_whoregion  year  e_pop_num  e_inc_100k  e_inc_num  \
# 0     Afghanistan  AFG         EMR  2000   19542982       190.0      37000
# 1     Afghanistan  AFG         EMR  2001   19688632       189.0      37000
# 2     Afghanistan  AFG         EMR  2002   21000256       189.0      40000
# 3     Afghanistan  AFG         EMR  2003   22645130       189.0      43000
# 4     Afghanistan  AFG         EMR  2004   23553551       189.0      44000
# ...           ...  ...         ...   ...        ...         ...        ...
# 4697     Zimbabwe  ZWE         AFR  2017   14751101       221.0      33000
# 4698     Zimbabwe  ZWE         AFR  2018   15052184       210.0      32000
# 4699     Zimbabwe  ZWE         AFR  2019   15354608       199.0      31000
# 4700     Zimbabwe  ZWE         AFR  2020   15669666       181.0      28000
# 4701     Zimbabwe  ZWE         AFR  2021   15993524       190.0      30000
#
#       e_tbhiv_prct  e_inc_tbhiv_100k  e_inc_tbhiv_num  e_mort_exc_tbhiv_100k  \
# 0             0.02              0.03              6.0                   68.0
# 1             0.01              0.03              6.0                   63.0
# 2             0.01              0.03              6.0                   57.0
# 3             0.01              0.03              6.0                   58.0
# 4             0.01              0.03              6.0                   51.0
# ...            ...               ...              ...                    ...
# 4697         63.00            140.00          21000.0                    8.3
# 4698         62.00            130.00          20000.0                    7.7
# 4699         60.00            119.00          18000.0                   11.0
# 4700         61.00            108.00          17000.0                   12.0
# 4701         62.00            116.00          18000.0                   13.0
#
#       e_mort_exc_tbhiv_num  e_mort_tbhiv_100k  e_mort_tbhiv_num  e_mort_100k  \
# 0                  13000.0               0.17              33.0         68.0
# 1                  12000.0               0.30              60.0         63.0
# 2                  12000.0               0.27              57.0         57.0
# 3                  13000.0               0.29              66.0         58.0
# 4                  12000.0               0.29              67.0         52.0
# ...                    ...                ...               ...          ...
# 4697                1200.0              27.00            4000.0         35.0
# 4698                1200.0              24.00            3600.0         32.0
# 4699                1700.0              31.00            4800.0         43.0
# 4700                1800.0              30.00            4700.0         42.0
# 4701                2000.0              33.00            5300.0         46.0
#
#       e_mort_num  c_newinc_100k  c_cdr
# 0        13000.0           36.0   19.0
# 1        12000.0           51.0   27.0
# 2        12000.0           66.0   35.0
# 3        13000.0           61.0   32.0
# 4        12000.0           78.0   41.0
# ...          ...            ...    ...
# 4697      5200.0          175.0   79.0
# 4698      4800.0          167.0   80.0
# 4699      6600.0          137.0   69.0
# 4700      6600.0          100.0   55.0
# 4701      7300.0          102.0   54.0
#
# [4702 rows x 18 columns]

# %%
tb_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4702 entries, 0 to 4701
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                4702 non-null   object
#  1   iso3                   4702 non-null   object
#  2   g_whoregion            4702 non-null   object
#  3   year                   4702 non-null   int64
#  4   e_pop_num              4702 non-null   int64
#  5   e_inc_100k             4702 non-null   float64
#  6   e_inc_num              4702 non-null   int64
#  7   e_tbhiv_prct           4057 non-null   float64
#  8   e_inc_tbhiv_100k       4057 non-null   float64
#  9   e_inc_tbhiv_num        4057 non-null   float64
#  10  e_mort_exc_tbhiv_100k  4680 non-null   float64
#  11  e_mort_exc_tbhiv_num   4680 non-null   float64
#  12  e_mort_tbhiv_100k      4680 non-null   float64
#  13  e_mort_tbhiv_num       4680 non-null   float64
#  14  e_mort_100k            4680 non-null   float64
#  15  e_mort_num             4680 non-null   float64
#  16  c_newinc_100k          4529 non-null   float64
#  17  c_cdr                  4424 non-null   float64
# dtypes: float64(12), int64(3), object(3)
# memory usage: 661.3+ KB

# %%
tb_new.isnull().sum()
# Out:
# country                    0
# iso3                       0
# g_whoregion                0
# year                       0
# e_pop_num                  0
# e_inc_100k                 0
# e_inc_num                  0
# e_tbhiv_prct             645
# e_inc_tbhiv_100k         645
# e_inc_tbhiv_num          645
# e_mort_exc_tbhiv_100k     22
# e_mort_exc_tbhiv_num      22
# e_mort_tbhiv_100k         22
# e_mort_tbhiv_num          22
# e_mort_100k               22
# e_mort_num                22
# c_newinc_100k            173
# c_cdr                    278
# dtype: int64

# %%
tb_data = tb_new.fillna(0)

display(tb_data)
# Out:
#           country iso3 g_whoregion  year  e_pop_num  e_inc_100k  e_inc_num  \
# 0     Afghanistan  AFG         EMR  2000   19542982       190.0      37000
# 1     Afghanistan  AFG         EMR  2001   19688632       189.0      37000
# 2     Afghanistan  AFG         EMR  2002   21000256       189.0      40000
# 3     Afghanistan  AFG         EMR  2003   22645130       189.0      43000
# 4     Afghanistan  AFG         EMR  2004   23553551       189.0      44000
# ...           ...  ...         ...   ...        ...         ...        ...
# 4697     Zimbabwe  ZWE         AFR  2017   14751101       221.0      33000
# 4698     Zimbabwe  ZWE         AFR  2018   15052184       210.0      32000
# 4699     Zimbabwe  ZWE         AFR  2019   15354608       199.0      31000
# 4700     Zimbabwe  ZWE         AFR  2020   15669666       181.0      28000
# 4701     Zimbabwe  ZWE         AFR  2021   15993524       190.0      30000
#
#       e_tbhiv_prct  e_inc_tbhiv_100k  e_inc_tbhiv_num  e_mort_exc_tbhiv_100k  \
# 0             0.02              0.03              6.0                   68.0
# 1             0.01              0.03              6.0                   63.0
# 2             0.01              0.03              6.0                   57.0
# 3             0.01              0.03              6.0                   58.0
# 4             0.01              0.03              6.0                   51.0
# ...            ...               ...              ...                    ...
# 4697         63.00            140.00          21000.0                    8.3
# 4698         62.00            130.00          20000.0                    7.7
# 4699         60.00            119.00          18000.0                   11.0
# 4700         61.00            108.00          17000.0                   12.0
# 4701         62.00            116.00          18000.0                   13.0
#
#       e_mort_exc_tbhiv_num  e_mort_tbhiv_100k  e_mort_tbhiv_num  e_mort_100k  \
# 0                  13000.0               0.17              33.0         68.0
# 1                  12000.0               0.30              60.0         63.0
# 2                  12000.0               0.27              57.0         57.0
# 3                  13000.0               0.29              66.0         58.0
# 4                  12000.0               0.29              67.0         52.0
# ...                    ...                ...               ...          ...
# 4697                1200.0              27.00            4000.0         35.0
# 4698                1200.0              24.00            3600.0         32.0
# 4699                1700.0              31.00            4800.0         43.0
# 4700                1800.0              30.00            4700.0         42.0
# 4701                2000.0              33.00            5300.0         46.0
#
#       e_mort_num  c_newinc_100k  c_cdr
# 0        13000.0           36.0   19.0
# 1        12000.0           51.0   27.0
# 2        12000.0           66.0   35.0
# 3        13000.0           61.0   32.0
# 4        12000.0           78.0   41.0
# ...          ...            ...    ...
# 4697      5200.0          175.0   79.0
# 4698      4800.0          167.0   80.0
# 4699      6600.0          137.0   69.0
# 4700      6600.0          100.0   55.0
# 4701      7300.0          102.0   54.0
#
# [4702 rows x 18 columns]

# %% [markdown]
# ## 3.) Exploratory Data Analysis

# %%
# Get descriptive statistics summary 

tb_data.describe(include = "all")
# Out:
#             country  iso3 g_whoregion        year     e_pop_num   e_inc_100k  \
# count          4702  4702        4702  4702.00000  4.702000e+03  4702.000000
# unique          217   217           6         NaN           NaN          NaN
# top     Afghanistan   AFG         EUR         NaN           NaN          NaN
# freq             22    22        1183         NaN           NaN          NaN
# mean            NaN   NaN         NaN  2010.53892  3.277924e+07   124.495904
# std             NaN   NaN         NaN     6.33931  1.301093e+08   186.966585
# min             NaN   NaN         NaN  2000.00000  1.343000e+03     0.000000
# 25%             NaN   NaN         NaN  2005.00000  7.488340e+05    12.000000
# 50%             NaN   NaN         NaN  2011.00000  5.830724e+06    46.000000
# 75%             NaN   NaN         NaN  2016.00000  2.102880e+07   164.000000
# max             NaN   NaN         NaN  2021.00000  1.425893e+09  1590.000000
#
#            e_inc_num  e_tbhiv_prct  e_inc_tbhiv_100k  e_inc_tbhiv_num  \
# count   4.702000e+03   4702.000000       4702.000000      4702.000000
# unique           NaN           NaN               NaN              NaN
# top              NaN           NaN               NaN              NaN
# freq             NaN           NaN               NaN              NaN
# mean    5.266572e+04     10.623392         31.853456      6278.367929
# std     2.643730e+05     16.461475        111.028057     30201.044171
# min     0.000000e+00      0.000000          0.000000         0.000000
# 25%     2.100000e+02      0.260000          0.070000         2.000000
# 50%     3.000000e+03      3.450000          1.000000        73.000000
# 75%     1.700000e+04     13.000000          8.700000      1200.000000
# max     3.800000e+06    100.000000       1320.000000    461000.000000
#
#         e_mort_exc_tbhiv_100k  e_mort_exc_tbhiv_num  e_mort_tbhiv_100k  \
# count             4702.000000           4702.000000        4702.000000
# unique                    NaN                   NaN                NaN
# top                       NaN                   NaN                NaN
# freq                      NaN                   NaN                NaN
# mean                14.748896           6765.165674          11.441948
# std                 22.613711          37716.619797          40.087637
# min                  0.000000              0.000000           0.000000
# 25%                  0.880000             16.000000           0.010000
# 50%                  4.100000            220.000000           0.190000
# 75%                 19.000000           1700.000000           2.200000
# max                188.000000         617000.000000         481.000000
#
#         e_mort_tbhiv_num  e_mort_100k     e_mort_num  c_newinc_100k  \
# count        4702.000000  4702.000000    4702.000000    4702.000000
# unique               NaN          NaN            NaN            NaN
# top                  NaN          NaN            NaN            NaN
# freq                 NaN          NaN            NaN            NaN
# mean         2211.541046    26.200806    8982.283071      71.166742
# std         10508.155339    54.734626   43308.434123     104.186133
# min             0.000000     0.000000       0.000000       0.000000
# 25%             0.000000     0.980000      18.000000       8.600000
# 50%            16.000000     4.600000     270.000000      34.000000
# 75%           330.000000    24.000000    2800.000000      92.000000
# max        181000.000000   533.000000  714000.000000     933.000000
#
#               c_cdr
# count   4702.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean      68.893003
# std       25.608232
# min        0.000000
# 25%       57.000000
# 50%       80.000000
# 75%       87.000000
# max      240.000000

# %% [markdown]
# ### a.) How many countries are in this data?

# %%
tb_analysis = tb_data[["country"]].nunique()
tb_analysis
# Out:
# country    217
# dtype: int64

# %%
#The countries are divided into the number of WHO regions. 

tb_analysis = tb_data[["g_whoregion"]].nunique()
tb_analysis
# Out:
# g_whoregion    6
# dtype: int64

# %% [markdown]
# ### b.) How many years does this data span across?

# %%
tb_analysis = tb_data[["year"]].nunique()
tb_analysis
# Out:
# year    22
# dtype: int64

# %% [markdown]
# ### c.) Display  sample data for a country such as Nigeria

# %%
# I am going to display a sample date of population, Incidence Number and the corresponding years and would be sorting it according to the year

tb_analysis = tb_data[(tb_data["country"] == "Nigeria")][["country", "year", "e_pop_num", "e_inc_num"]].sort_values(["year"])
tb_analysis
# Out:
#       country  year  e_pop_num  e_inc_num
# 3053  Nigeria  2000  122851984     269000
# 3054  Nigeria  2001  126152678     276000
# 3055  Nigeria  2002  129583026     284000
# 3056  Nigeria  2003  133119801     292000
# 3057  Nigeria  2004  136756848     300000
# 3058  Nigeria  2005  140490722     308000
# 3059  Nigeria  2006  144329764     316000
# 3060  Nigeria  2007  148294028     325000
# 3061  Nigeria  2008  152382506     334000
# 3062  Nigeria  2009  156595758     343000
# 3063  Nigeria  2010  160952853     353000
# 3064  Nigeria  2011  165463745     362000
# 3065  Nigeria  2012  170075932     373000
# 3066  Nigeria  2013  174726123     383000
# 3067  Nigeria  2014  179379016     393000
# 3068  Nigeria  2015  183995785     403000
# 3069  Nigeria  2016  188666931     413000
# 3070  Nigeria  2017  193495907     424000
# 3071  Nigeria  2018  198387623     435000
# 3072  Nigeria  2019  203304492     445000
# 3073  Nigeria  2020  208327405     456000
# 3074  Nigeria  2021  213401323     467000

# %% [markdown]
# ### d.) What is the Population, Number of cases(TB alone and TB with HIV) and Number of deaths as at the year 2021
#
# #### According to the data dictionary;
# ##### 1.) e_pop_num:        Estimated total population number
# ##### 2.) e_inc_num:        Estimated number of incident cases (all forms)
# ##### 3.) e_inc_tbhiv:      Estimated incidence of TB cases who are HIV-positive
# ##### 4.) e_mort_num:       Estimated mortality of TB cases (all forms)
# ##### 5.) e_mort_tbhiv_num: Estimated number of deaths from TB in people who are HIV-positive
# ##### 6.) e_tbhiv_prct:     Estimated HIV in incident TB (percent)

# %%
tb_analysis = tb_data[(tb_data["year"] == 2021)][["e_pop_num","e_inc_num","e_inc_tbhiv_num","e_mort_num","e_mort_tbhiv_num","e_tbhiv_prct"]].sum()
print(tb_analysis.astype(int))
# Out:
# e_pop_num           7880296494
# e_inc_num             10561049
# e_inc_tbhiv_num         701508
# e_mort_num             1544019
# e_mort_tbhiv_num        185721
# e_tbhiv_prct              1704
# dtype: int64

# %% [markdown]
# ### e. i) What is the total number of Estimated Incidences of Tuberculosis since the year 2000?

# %%
#The sum total of e_inc_number since 2000 till 2021

tb_analysis = tb_data[(tb_data["year"] >= 2000)][["e_inc_num"]].sum()
tb_analysis
# Out:
# e_inc_num    247634223
# dtype: int64

# %% [markdown]
# ### e. ii) What is the total number of Estimated incidences of Tuberculosis in HIV Positive Patients since the year 2000?

# %%
#The sum total of e_inc_tbhiv_num since 2000 till 2021

tb_analysis = tb_data[(tb_data["year"] >= 2000)][["e_inc_tbhiv_num"]].sum()
tb_analysis
# Out:
# e_inc_tbhiv_num    29520886.0
# dtype: float64

# %% [markdown]
# ### e. iii) What is the total number of Estimated Deaths from Tuberculosis from the year 2000 till date?

# %%
#The sum total of e_mort_num since 2000 till 2021

tb_analysis = tb_data[(tb_data["year"] >= 2000)][["e_mort_num"]].sum()
tb_analysis
# Out:
# e_mort_num    42234695.0
# dtype: float64

# %% [markdown]
# ### e. iv.) What is the total number of Estimated Deaths from Tuberculosis in People who are HIV positive since the year 2000?

# %%
#The sum total of e_mort_tbhiv_num since 2000 till 2021

tb_analysis = tb_data[(tb_data["year"] >= 2000)][["e_mort_tbhiv_num"]].sum()
tb_analysis
# Out:
# e_mort_tbhiv_num    10398666.0
# dtype: float64

# %% [markdown]
# ### f. i.) What is the number of Estimated incidence of Tuberculosis from year 2000 to 2021

# %%
tb_analysis1 = tb_data.groupby(["year"])[["e_inc_num"]].sum()
tb_analysis1_sort = pd.DataFrame(tb_analysis1.sort_values('e_inc_num', ascending = False))
tb_analysis1_sort
# Out:
#       e_inc_num
# year
# 2006   11820137
# 2005   11818293
# 2007   11779003
# 2004   11763157
# 2008   11730656
# 2009   11697437
# 2003   11688601
# 2010   11577028
# 2002   11542345
# 2011   11508867
# 2012   11430028
# 2001   11391969
# 2013   11298039
# 2000   11236210
# 2014   11194203
# 2015   11073502
# 2016   10884752
# 2017   10669173
# 2021   10561049
# 2018   10517440
# 2019   10344553
# 2020   10107781

# %% [markdown]
# ### f. ii.) A line Chart showing the plot of Tuberculosis Incidence across 22 years

# %%
# figure
fig, ax = plt.subplots(1, figsize=(12,4), facecolor='#293952')
ax.set_facecolor('#293952')
# data
TB_cases = tb_analysis1_sort['e_inc_num']
# plot
plt.plot(tb_analysis1_sort.index, TB_cases, marker='o', markersize=8, color='#FDAC53', linewidth=0.5)
# ticks n title
ax.tick_params(axis='both', colors='w')
plt.xticks(tb_analysis1_sort.index[::1])
plt.title('Number of TB cases', loc='right', color='w', fontsize=14)
# spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('w')
ax.spines['bottom'].set_color('w')
# grid
ax.set_axisbelow(True)
ax.yaxis.grid(color='#FDAC53', linestyle='dashed', alpha=0.5)
plt.show()

# %% [markdown]
# ### g. i.) what is the estimated number of deaths from Tuberculosis for the years 2000 to 2021?

# %%
tb_analysis2 = tb_data.groupby(["year"])[["e_mort_num"]].sum()
tb_analysis2_sort = pd.DataFrame(tb_analysis2.sort_values('e_mort_num', ascending = False))
tb_analysis2_sort
# Out:
#       e_mort_num
# year
# 2000   2390424.0
# 2001   2362987.0
# 2002   2320594.0
# 2003   2287647.0
# 2005   2238531.0
# 2004   2221253.0
# 2006   2200045.0
# 2007   2165951.0
# 2008   2099399.0
# 2009   2045607.0
# 2010   1988769.0
# 2011   1888412.0
# 2012   1820529.0
# 2013   1769911.0
# 2014   1714857.0
# 2015   1655087.0
# 2016   1599610.0
# 2017   1544630.0
# 2021   1544019.0
# 2020   1488567.0
# 2018   1471977.0
# 2019   1415889.0

# %% [markdown]
# ### g. ii.) A line Chart showing the estimated number of deaths from Tuberculosis across 22 years

# %%
# figure
fig, ax = plt.subplots(1, figsize=(12,4), facecolor='#293952')
ax.set_facecolor('#293952')
# data
TB_deaths = tb_analysis2_sort['e_mort_num']
# plot
plt.plot(tb_analysis2_sort.index, TB_deaths, marker='o', markersize=8, color='#FDAC53', linewidth=0.5)
# ticks n title
ax.tick_params(axis='both', colors='w')
plt.xticks(tb_analysis1_sort.index[::1])
plt.title('Number of TB deaths', loc='right', color='w', fontsize=14)
# spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('w')
ax.spines['bottom'].set_color('w')
# grid
ax.set_axisbelow(True)
ax.yaxis.grid(color='#FDAC53', linestyle='dashed', alpha=0.5)
plt.show()

# %% [markdown]
# ### h.) What Countries had the highest incidence of Tuberculosis?
#
# I am going to show the Top 10 Countries with the highest estimated incidence of tuberculosis.

# %%
tb_analysis_by_country = tb_data.groupby(["country"])[["country", "e_inc_num",]].sum()
tb_analysis_by_country = pd.DataFrame(tb_analysis_by_country.sort_values('e_inc_num', ascending = False))
tb_analysis_by_country.head(10)
# Out:
#               e_inc_num
# country
# India          76650000
# China          22929000
# Indonesia      18377000
# Philippines    11612000
# Pakistan       11600000
# South Africa   11310000
# Nigeria         7954000
# Bangladesh      7290000
# Myanmar         5005000
# Ethiopia        4965000

# %% [markdown]
# ### i.) Countries with the highest number of deaths from Tuberculosis
#
# i am going to show the Top 10 countries with highest estimated number of deaths from tuberculosis

# %%
tb_analysis_by_country_in_mortality = tb_data.groupby(["country"])[["country", "e_inc_tbhiv_num","e_inc_num","e_mort_tbhiv_num","e_mort_num"]].sum()
tb_analysis_by_country_in_mortality = pd.DataFrame(tb_analysis_by_country_in_mortality.sort_values('e_mort_num', ascending = False))
tb_analysis_by_country_in_mortality.head(10)
# Out:
#                                   e_inc_tbhiv_num  e_inc_num  \
# country
# India                                   4139000.0   76650000
# Nigeria                                 1489000.0    7954000
# South Africa                            7526000.0   11310000
# Indonesia                                395500.0   18377000
# Bangladesh                                10749.0    7290000
# United Republic of Tanzania             1584000.0    3851000
# Kenya                                   1761000.0    4129000
# China                                    398000.0   22929000
# Democratic Republic of the Congo         819000.0    4950000
# Ethiopia                                 868100.0    4965000
#
#                                   e_mort_tbhiv_num  e_mort_num
# country
# India                                    1101600.0  12410000.0
# Nigeria                                   898000.0   3059000.0
# South Africa                             2272000.0   2850000.0
# Indonesia                                 102770.0   2523000.0
# Bangladesh                                  3633.0   1596000.0
# United Republic of Tanzania               819800.0   1447000.0
# Kenya                                     794000.0   1370000.0
# China                                      99200.0   1331000.0
# Democratic Republic of the Congo          348100.0   1220000.0
# Ethiopia                                  372600.0   1204000.0

# %% [markdown]
# ## 4.) Data Export
#
# I exported the dataset to create a visualization using Tableau and Figma

# %%
tb_data.to_csv('./tb_data.csv', index=False, header=True)
